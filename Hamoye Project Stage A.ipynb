# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')

# %%
url = 'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
fuel_data = pd.read_csv(url, error_bad_lines=False)

# %%
fuel_data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
arr = np.array(fuel_data['fuel_mmbtu_per_unit'])

# %%
np.std(arr)
# Out:
# 10.600040781503973

# %%
np.percentile(arr, 75, axis=None, out=None)
# Out:
# 17.006

# %%
sns.pairplot(data=fuel_data)

# %%
sns.heatmap(fuel_data.isnull(),yticklabels=False,cbar=False, cmap="viridis")

# %%
fuel_data['fuel_unit'].isnull().value_counts()
# Out:
# False    29343
# True       180
# Name: fuel_unit, dtype: int64

# %%
fuel_data['fuel_unit'].isnull().count()
# Out:
# 29523

# %%
arr = np.array(fuel_data['fuel_qty_burned'])


kurtosis_pandas = pd.DataFrame(arr).kurtosis()[0]

print(kurtosis_pandas)
# -0.5270409758168872
# -0.31467107631025604


skew_pandas = pd.DataFrame(arr).skew()[0]

print(skew_pandas)
# Out:
# 651.3694501337732
# 15.851495469109503

# %%
arr = np.array(fuel_data['fuel_cost_per_mmbtu'])

# %%
np.percentile(arr, 75, axis=None, out=None)
# Out:
# 7.745

# %%
fuel_data['fuel_cost_per_unit_burned'].min()
# Out:
# -276.08

# %%
fuel_data[fuel_data['fuel_cost_per_unit_burned'] == -276.08]
# Out:
#                     record_id  utility_id_ferc1  report_year  \
# 7733  f1_fuel_2000_12_194_3_3               194         2000
#
#          plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 7733  nelson dewey unit 2               waste       ton             39.0
#
#       fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 7733               0.0155                    -276.08
#
#       fuel_cost_per_unit_delivered  fuel_cost_per_mmbtu
# 7733                       -174.67               -8.906

# %%
sns.barplot(x='report_year', data=fuel_data)
# Out:
# C:\Users\ACER\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(fuel_data['report_year'], bins=50)
# Out:
# C:\Users\ACER\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fuel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
# record_id                       29523 non-null object
# utility_id_ferc1                29523 non-null int64
# report_year                     29523 non-null int64
# plant_name_ferc1                29523 non-null object
# fuel_type_code_pudl             29523 non-null object
# fuel_unit                       29343 non-null object
# fuel_qty_burned                 29523 non-null float64
# fuel_mmbtu_per_unit             29523 non-null float64
# fuel_cost_per_unit_burned       29523 non-null float64
# fuel_cost_per_unit_delivered    29523 non-null float64
# fuel_cost_per_mmbtu             29523 non-null float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB

# %%
A = [1,2,3,4,5,6]
B = [13, 21, 34]

# %%
A_B = A.append(B)

# %%
print(A_B)
# Out:
# None

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])
